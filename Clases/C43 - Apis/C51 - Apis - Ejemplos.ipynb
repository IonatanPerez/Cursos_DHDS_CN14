# %%
import requests
from tqdm import tqdm

# %%
url = "https://api.mercadolibre.com/items/MLA1103923706"
r = requests.get(url)

# %%
json = r.json()

# %%
json['price']
# Out:
# 983

# %%
dir(r)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
r.content
# Out:
# b'<!DOCTYPE html>\n<html lang=en>\n  <meta charset=utf-8>\n  <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">\n  <title>Error 404 (Not Found)!!1</title>\n  <style>\n    *{margin:0;padding:0}html,code{font:15px/22px arial,sans-serif}html{background:#fff;color:#222;padding:15px}body{margin:7% auto 0;max-width:390px;min-height:180px;padding:30px 0 15px}* > body{background:url(//www.google.com/images/errors/robot.png) 100% 5px no-repeat;padding-right:205px}p{margin:11px 0 22px;overflow:hidden}ins{color:#777;text-decoration:none}a img{border:0}@media screen and (max-width:772px){body{background:none;margin-top:0;max-width:none;padding-right:0}}#logo{background:url(//www.google.com/images/branding/googlelogo/1x/googlelogo_color_150x54dp.png) no-repeat;margin-left:-5px}@media only screen and (min-resolution:192dpi){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) no-repeat 0% 0%/100% 100%;-moz-border-image:
# ...

# %%
url = "https://api.mercadolibre.com/sites/MLA/categories"
r = requests.get(url)
r.json()
# Out:
# [{'id': 'MLA5725', 'name': 'Accesorios para Vehículos'},
#  {'id': 'MLA1512', 'name': 'Agro'},
#  {'id': 'MLA1403', 'name': 'Alimentos y Bebidas'},
#  {'id': 'MLA1071', 'name': 'Animales y Mascotas'},
#  {'id': 'MLA1367', 'name': 'Antigüedades y Colecciones'},
#  {'id': 'MLA1368', 'name': 'Arte, Librería y Mercería'},
#  {'id': 'MLA1743', 'name': 'Autos, Motos y Otros'},
#  {'id': 'MLA1384', 'name': 'Bebés'},
#  {'id': 'MLA1246', 'name': 'Belleza y Cuidado Personal'},
#  {'id': 'MLA1039', 'name': 'Cámaras y Accesorios'},
#  {'id': 'MLA1051', 'name': 'Celulares y Teléfonos'},
#  {'id': 'MLA1648', 'name': 'Computación'},
#  {'id': 'MLA1144', 'name': 'Consolas y Videojuegos'},
#  {'id': 'MLA1500', 'name': 'Construcción'},
#  {'id': 'MLA1276', 'name': 'Deportes y Fitness'},
#  {'id': 'MLA5726', 'name': 'Electrodomésticos y Aires Ac.'},
#  {'id': 'MLA1000', 'name': 'Electrónica, Audio y Video'},
#  {'id': 'MLA2547', 'name': 'Entradas para Eventos'},
# ...

# %%
url = "https://api.mercadolibre.com/questions/search?item_id=MLA903688057"
r = requests.get(url)
r.json()

# %%
url = "https://api.mercadolibre.com/sites/MLA/search?q=olla&offset=101"
r = requests.get(url)
r.json()['results']
# Out:
# [{'id': 'MLA1287994442',
#   'title': 'Olla Tramontina Allegra 24  Cm 5,7 Lts Acero Oferta',
#   'condition': 'new',
#   'thumbnail_id': '649847-MLA44877116908_022021',
#   'catalog_product_id': 'MLA19996022',
#   'listing_type_id': 'gold_pro',
#   'permalink': 'https://www.mercadolibre.com.ar/olla-tramontina-allegra-24-cm-57-lts-acero-oferta/p/MLA19996022',
#   'buying_mode': 'buy_it_now',
#   'site_id': 'MLA',
#   'category_id': 'MLA9181',
#   'domain_id': 'MLA-KITCHEN_POTS',
#   'thumbnail': 'http://http2.mlstatic.com/D_649847-MLA44877116908_022021-I.jpg',
#   'currency_id': 'ARS',
#   'order_backend': 1,
#   'price': 18779,
#   'original_price': None,
#   'sale_price': None,
#   'sold_quantity': 0,
#   'available_quantity': 1,
#   'official_store_id': None,
#   'use_thumbnail_id': True,
#   'accepts_mercadopago': True,
#   'tags': ['good_quality_picture',
#    'good_quality_thumbnail',
#    'mshops_ahora-6',
#    'immediate_payment',
#    'cart_eligible',
# ...

# %%
import pandas as pd

data = pd.DataFrame(r.json()['results'])
data
# Out:
#                id                                              title  \
# 0   MLA1287994442  Olla Tramontina Allegra 24  Cm 5,7 Lts Acero O...
# 1   MLA1152357290  Olla A Presión 7 Litros Marmicoc Olltrat07 T07...
# 2   MLA1100832118  Bateria De Cocina Set Ollas Allegra 4 Pzs Tram...
# 3    MLA929609347  Cacerola Tefal Pratika 24 Cm Olla Tapa Vidrio ...
# 4    MLA852054216  Olla Pochoclera  Familiar Jovifel Con Cuchara ...
# 5    MLA901025302  Juego De Ollas Set De 4 Piezas Tramontina Alle...
# 6   MLA1118109454  Set 7 Piezas Cocina Bateria Ollas Cacerola Sar...
# 7   MLA1302524260       Cacerola Hudson Antiadherente Ceramico 24 Cm
# 8    MLA886153965      Cacerola Antiadherente Hudson  26 Cm Aluminio
# 9    MLA856305306  Cacerola Teflón Antiadherente Hudson Nº 28 Con...
# 10  MLA1281450187  Batería Hudson Juego Set Cocina Cerámica Cubie...
# 11   MLA874586798  Cacerola Honda Tramontina Grano Inox 24cm 5,8l...
# 12   MLA826585754  Olla A Presion Panelux 10 Litros Aluminio Puli...
# ...

# %%
import pickle

with open('prueba.pick', 'wb') as file:
    pickle.dump(r.json(),file)

# %%
import pickle
with open('prueba.pick', 'rb') as file:
    data = pickle.load(file)

# %%
data
# Out:
# {'site_id': 'MLA',
#  'country_default_time_zone': 'GMT-03:00',
#  'query': 'olla',
#  'paging': {'total': 15136,
#   'primary_results': 1000,
#   'offset': 101,
#   'limit': 50},
#  'results': [{'id': 'MLA1287994442',
#    'title': 'Olla Tramontina Allegra 24  Cm 5,7 Lts Acero Oferta',
#    'condition': 'new',
#    'thumbnail_id': '649847-MLA44877116908_022021',
#    'catalog_product_id': 'MLA19996022',
#    'listing_type_id': 'gold_pro',
#    'permalink': 'https://www.mercadolibre.com.ar/olla-tramontina-allegra-24-cm-57-lts-acero-oferta/p/MLA19996022',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA9181',
#    'domain_id': 'MLA-KITCHEN_POTS',
#    'thumbnail': 'http://http2.mlstatic.com/D_649847-MLA44877116908_022021-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 1,
#    'price': 18779,
#    'original_price': None,
#    'sale_price': None,
#    'sold_quantity': 0,
#    'available_quantity': 1,
#    'official_store_id': None,
# ...

# %%
datos = []
for i in tqdm(range(100)):
    url = f"https://api.mercadolibre.com/items/MLA9144597{i}/"
    r = requests.get(url)
    datos.append(r.json())
# Out:
# 100%|██████████| 100/100 [00:21<00:00,  4.61it/s]

# %%
import pandas as pd

# %%
data = pd.DataFrame(datos)

# %%
data
# Out:
#                                message      error  status cause            id  \
# 0   Item with id MLA91445970 not found  not_found     404    []           NaN
# 1   Item with id MLA91445971 not found  not_found     404    []           NaN
# 2   Item with id MLA91445972 not found  not_found     404    []           NaN
# 3   Item with id MLA91445973 not found  not_found     404    []           NaN
# 4   Item with id MLA91445974 not found  not_found     404    []           NaN
# ..                                 ...        ...     ...   ...           ...
# 95                                 NaN        NaN  paused   NaN  MLA914459795
# 96                                 NaN        NaN  closed   NaN  MLA914459796
# 97                                 NaN        NaN  closed   NaN  MLA914459797
# 98                                 NaN        NaN  paused   NaN  MLA914459798
# 99                                 NaN        NaN  paused   NaN  MLA914459799
#
# ...
